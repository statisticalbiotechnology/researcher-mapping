# %%
import numpy as np
from numpy.linalg import norm

# %%
from gensim.test.utils import get_tmpfile
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec
fname = get_tmpfile("doc2vec_more_school_1000_onlyDocId")

# %%
class EpochLogger(CallbackAny2Vec):
    '''Callback to log information about training'''
    def __init__(self):
        self.epoch = 0
    def on_epoch_begin(self, model):
         print("Epoch #{} start".format(self.epoch))
    def on_epoch_end(self, model):
        print("Epoch #{} end".format(self.epoch))
        self.epoch += 1

# %%
epoch_logger = EpochLogger()

# %%
model = Word2Vec.load(fname)
# Out:
# /home/ekvall/anaconda3/envs/kth-cluster/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# !pwd
# Out:
# /home/ekvall/kthLife/python

# %%
model.save("./assets/doc2vecModel/onlyDoc1000/onlyDoc1000")

# %%
model.

# %%
start = time.time()
model.most_similar(positive=word_list)
end = time.time()
print(end - start)
# Out:
# 0.03019881248474121
# /home/ekvall/anaconda3/envs/kth-cluster/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).

# %%
start = time.time()
words_vector = list()
for w in word_list:
    words_vector.append(model[str(w).lower()])
model.wv.most_similar([np.sum(words_vector, axis=0)])

np.sum(np.asarray(words_vector), axis=0)
end = time.time()
print(end - start)
# Out:
# 0.014617681503295898

# %%
np.asarray(words_vector).shape
# Out:
# (3, 300)

# %%
model[word_list].shape
# Out:
# (3, 300)

# %%
start = time.time()
words_vector = list()
arr = np.zeros((len(word_list), 300))
for i, w in enumerate(word_list):
    arr[i,:] = model[str(w).lower()]
    
np.sum(arr, axis=0)
end = time.time()
print(end - start)
# Out:
# 0.00028777122497558594

# %%
start = time.time()
model.wv.most_similar([np.sum(model[word_list], axis=0)], topn=1_000)
end = time.time()
print(end - start)
# Out:
# 0.01600193977355957

# %%
import time

start = time.time()
print("hello")
end = time.time()
print(end - start)
# Out:
# hello
# 6.842613220214844e-05

# %%
from numpy import exp, dot
from gensim import matutils

def predict_output_context(model, center_word, topn=1_000):
    word = model.wv.vocab[center_word]
    vec = model.wv.vectors[word.index]
    prob_values = exp(dot(vec, model.trainables.syn1neg.T))
    prob_values /= sum(prob_values)
    top_indices = matutils.argsort(prob_values, topn=topn, reverse=True)
    return [(model.wv.index2word[index1], prob_values[index1]) for index1 in top_indices]

# %%
word_list = ["dogs","in","africa","is"]

# %%
word_list
# Out:
# ['dogs', 'in', 'africa', 'is']

# %%
model.docvecs.most_similar([np.sum(model[word_list], axis=0)], topn=1_0)
# Out:
# [('47224071', 0.4096948206424713),
#  ('79811_Uppsala', 0.3953573405742645),
#  ('60398_SU', 0.39533692598342896),
#  ('31944_Uppsala', 0.38942819833755493),
#  ('62658_SU', 0.3831539750099182),
#  ('50755_SU', 0.3825274705886841),
#  ('66891_Uppsala', 0.3803877830505371),
#  ('74064_Uppsala', 0.36933988332748413),
#  ('39551_SU', 0.3692159354686737),
#  ('51651_Uppsala', 0.3676477372646332)]

# %%
strX = np.sum(model[word_list], axis=0)

# %%
docId = model["79811_Uppsala"]

# %%
sklearn.metrics.pairwise.cosine_similarity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-9f60cf2dd2ba> in <module>
# ----> 1 sklearn.metrics.pairwise.cosine_similarity
#
# NameError: name 'sklearn' is not defined

# %%
round(np.dot(strX, docId) / (norm(strX)*norm(docId)),3)
# Out:
# 0.395

# %%
import time

start = time.time()
v = predict_output_context(model, "the")
end = time.time()
print(end - start)
# Out:
# 0.08325409889221191

# %%
v
# Out:
# [('glasnost', 0.0006011575),
#  ('perestroika', 0.00050239434),
#  ('matisse', 0.00047461587),
#  ('heyyati', 0.00045951002),
#  ('nccp', 0.0004349483),
#  ('hepiii', 0.0004338455),
#  ('journalism', 0.0004274509),
#  ('presidencies', 0.00040433512),
#  ('soviet', 0.0004026073),
#  ('genderism', 0.00039802364),
#  ('isisp', 0.00039798583),
#  ('ukrainian', 0.00039011406),
#  ('euromaidan', 0.00038387938),
#  ('hyperlocal', 0.00037872462),
#  ('prophet', 0.0003669382),
#  ('ukraine', 0.00036190051),
#  ('journalists', 0.00034002092),
#  ('fateful', 0.00033654177),
#  ('communist', 0.00033407597),
#  ('corrugatum', 0.00032992277),
#  ('ahmadinejad', 0.0003261777),
#  ('roma', 0.00032376143),
#  ('transfiguration', 0.00032075078),
#  ('zarathustra', 0.00031739683),
#  ('romani', 0.0003128452),
#  ('oun', 0.0003069408),
#  ('heidegger', 0.0002966202),
#  ('gibelio', 0.00028448668),
#  ('manliness', 0.0002840134),
#  ('russia', 0.00026590892),
#  ('cbnrm', 0.00026424436),
# ...

# %%
model.wv.vocab["the model"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-22863dbdad91> in <module>
# ----> 1 model.wv.vocab["the model"]
#
# KeyError: 'the model'
